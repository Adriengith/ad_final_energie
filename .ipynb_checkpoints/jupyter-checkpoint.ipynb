# %%
import pandas as pd

# %%
#df = pd.read_csv('', sep = ',')
df = pd.read_csv('data/donnees-electricite-2008a2017/donnees_elec_2017.csv', sep = ';', encoding='latin-1')

value = df.iloc[nb,:]
print(value[4])
# Out:
#                     OPERATEUR  ANNEE FILIERE      TYPE       CODE CONSOA  \
# 0                         SRD   2017       E    Region         24   0,00
# 1                         SRD   2017       E    Region         75   0,00
# 2         GEREDIS Deux-Sèvres   2017       E  InterCom  200040244   0,00
# 3         GEREDIS Deux-Sèvres   2017       E  InterCom  200041317   0,00
# 4         GEREDIS Deux-Sèvres   2017       E  InterCom  200041333   0,00
# ...                       ...    ...     ...       ...        ...    ...
# 52268  Electricité de Mayotte   2017       E   Commune      97613   0,00
# 52269  Electricité de Mayotte   2017       E   Commune      97614   6,20
# 52270  Electricité de Mayotte   2017       E   Commune      97615   7,70
# 52271  Electricité de Mayotte   2017       E   Commune      97616   1,40
# 52272  Electricité de Mayotte   2017       E   Commune      97617  57,90
#
#        PDLA  INDQUALA   CONSOI  PDLI  ... PDLT  INDQUALT    CONSOR  PDLR  \
# ...
